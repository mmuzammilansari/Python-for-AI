# %% [markdown]
# oop : object oriented programming
# class: a blueprint or template for creating objects
# object: An instance of a class
# Encapsulation: protect data from direct access
# Abstraction: Hide unnecesary details
# Polymorphis: Allow the same method but behave differently
# Inheritance:

# %%
print(1)
# Out:
# 1

# %%
class BankAccount:
    Bank_name="HBL"
    total_accounts=0
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
        BankAccount.total_accounts += 1
    def deposite(self, amount):
        self.balance +=amount
    def withdraw(self, amount):
        self.balance -= amount
    
    
        
a1 = BankAccount("ali", 1000)
print(a1.balance)
a1.deposite(2000)
print(a1.balance)
a1.withdraw(500)
print(a1.balance)
# print(a1.owner, a1.balance)
# print(sara.owner, sara.balance)
# Out:
# 1000
# 3000
# 2500

# %% [markdown]
# bankaccount is a class and a1 is the objects

# %%
a2 = BankAccount("sara", 2000)

print(BankAccount.total_accounts)
# Out:
# 17

# %%
class car:
    def __init__(self, colour,speed, fuel):
        self.colour = colour
        self.speed = speed
        self.fuel = fuel
    def accerate(self):
        print("accerating")
    def brake(self):
        print("braking")

# %%
c1 = car("Black", 200, "petrol")

# %%
# list of marks
class Student:
    total_students = 0
    def __init__(self, name, marks):
        self.name= name
        self.marks = list(marks)
        Student.total_students +=1
    def average(self):
        total = 0
        # return sum(marks) / len(marks)
        for i in self.marks:
            total += i
        return total / len(self.marks)
    
    def grade(self):
        if self.average()>=80:
            return "A"
        elif self.average()>=70:
            return "B"
        elif self.average()>=60:
            return "C"
        else:
            return "FAIL"

# %%
s1 = Student("Fatima", [85, 92, 78, 95,88,100])

# %%
s1.average()
# Out:
# 89.66666666666667

# %%
s1.grade()
# Out:
# 'A'

# %%
s2 = Student("abc", [85, 92, 78, 95,88,100])
s3 = Student("xyz", [85, 92, 78, 95,88,100])

# %%
print(Student.total_students)
# Out:
# 3

# %%
class BankAccount:
    Bank_name="HBL"
    total_accounts=0
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
        BankAccount.total_accounts += 1
    def deposite(self, amount):
        self.balance +=amount
    def withdraw(self, amount):
        self.balance -= amount

    def transfer(self, BankAccount, amount):
        if self.balance > amount:
            self.withdraw(amount)
            BankAccount.deposite(amount)
            print("Amount Transfered")
        else:
            print("Insufficient Amount")

# %%
A1 = BankAccount('ali', 10000)
A2 = BankAccount('sara', 2000)

print("A1 balance:",A1.balance)
print("A2 balance:",A2.balance)
A1.transfer(A2, 5000) 

print("A1 balance:",A1.balance)
print("A2 balance:",A2.balance)
# Out:
# A1 balance: 10000
# A2 balance: 2000
# Amount Transfered
# A1 balance: 5000
# A2 balance: 7000

# %%
class Product:
    def __init__(self, name, price, cost):
        self.name = name
        self.price = price      # what we sell it for
        self.cost = cost        # what we paid for it

    def profit(self):
        return self.price - self.cost


class Cart:
    def __init__(self):
        self.items = []         # each cart starts empty, with its own list

    def add(self, product, qty=1):
        self.items.append((product, qty))

    def total(self):
        return sum(p.price * qty for p, qty in self.items)

    def profit(self):
        return sum(p.profit() * qty for p, qty in self.items)


mouse    = Product("Mouse", 1500, 900)
keyboard = Product("Keyboard", 3500, 2200)

cart = Cart()
cart.add(mouse, 2)
cart.add(keyboard)

print("Total charged: Rs", cart.total())
print("Shop keeps:    Rs", cart.profit())
# Out:
# Total charged: Rs 6500
# Shop keeps:    Rs 2500

# %%
currency = "Rs- "
